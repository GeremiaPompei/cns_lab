# %% [markdown]
# # Sequential MNIST loader
#
# Notebook used to load output variables of sequential MNIST analysis.

# %% [markdown]
# Accuracy table of sequential MNIST analysis using following models:
# - RNN
# - LSTM
# - GRU
# - AntisymmetricRNN
#
# Results are related to sequential MNSIT and permuted sequential MNIST.

# %%
import pandas as pd

pd.read_json('sequential_mnist/variables/accuracy_table.json').T
# Out:
#                                   training_accuracy_mean  \
# rnn_seq_mnist                                   0.399032
# lstm_seq_mnist                                  0.925992
# gru_seq_mnist                                   0.942565
# antisymmetric_rnn_seq_mnist                     0.671491
# rnn_permuted_mnist                              0.609872
# lstm_permuted_mnist                             0.711218
# gru_permuted_mnist                              0.781731
# antisymmetric_rnn_permuted_mnist                0.499623
#
#                                   training_accuracy_std  test_accuracy_mean  \
# rnn_seq_mnist                                  0.040371            0.401336
# lstm_seq_mnist                                 0.041518            0.924383
# gru_seq_mnist                                  0.030199            0.940913
# antisymmetric_rnn_seq_mnist                    0.017530            0.679975
# ...
